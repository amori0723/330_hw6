# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw6.ipynb")

# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 6: Clustering
# ### Associated lectures: Lectures 15 and 16
#
# **Due date: [Mar 17, 11:59 pm](https://github.com/UBC-CS/cpsc330-2024W2?tab=readme-ov-file#deliverable-due-dates-tentative)**

# %% [markdown]
# ## Imports <a name="im"></a>

# %%
import os
from hashlib import sha1

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline
pd.set_option("display.max_colwidth", 0)

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ## Submission instructions
# <hr>
# rubric={points:6}
#
# **Please be aware that this homework assignment requires installation of several packages in your course environment. It's possible that you'll encounter installation challenges, which might be frustrating. However, remember that solving these issues is not wasting time but it is an essential skill for anyone aspiring to work in data science or machine learning.**
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330-2024W2/blob/main/docs/homework_instructions.md).
#
# **You may work in a group on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 4.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
#
#
# When you are ready to submit your assignment do the following:
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 4. Make sure that the plots and output are rendered properly in your submitted file.
# 5. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb. If the pdf or html also fail to render on Gradescope, please create two files for your homework: hw6a.ipynb with Exercise 1 and hw6b.ipynb with Exercises 2 and 3 and submit these two files in your submission.
# </div>
#
# _Points:_ 6

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: Document clustering warm-up
# <hr>
#
# In this homework, we will explore a popular application of clustering called [**document clustering**](https://en.wikipedia.org/wiki/Document_clustering). A large amount of unlabeled text data is available out there (e.g., news, recipes, online Q&A, tweets), and clustering is a commonly used technique to organize this data in a meaningful way.
#
# As a warm up, in this exercise you will cluster sentences from a toy corpus. Later in the homework you will work with a real corpus.
#
# The code below extracts introductory sentences of Wikipedia articles on a set of queries. To run the code successfully, you will need the `wikipedia` package installed in the course environment.
#
# ```
# conda activate cpsc330
# conda install -c conda-forge wikipedia
# ```
#
#
# **Your tasks:**
#
# Run the code below which
# - extracts content of Wikipedia articles on a set of queries
# - tokenizes the text (i.e., separates sentences) and
# - stores the 2nd sentence in each article as a document representing that article
#
# > Feel free to experiment with Wikipedia queries of your choice. But stick to the provided list for the final submission so that it's easier for the TAs to grade your submission.
#
# > For tokenization we are using the `nltk` package. If you do not have this package in the course environment, you will have to install it.
#
# ```
# conda activate cpsc330
# conda install -c anaconda nltk
# ```
#
# Even if you have the package installed via the course `conda` environment, you might have to download `nltk` pre-trained models, which can be done with the code below.

# %%
import nltk

nltk.download("punkt")
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/mymac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/mymac/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import wikipedia
from nltk.tokenize import sent_tokenize, word_tokenize

queries = [
    "baguette food",
    "banana bread food",
    "bread food",
    "data science",
    "sports analytics",
    "football sport",
    "ice hockey",
]

wiki_dict = {"wiki query": [], "text": [], "n_words": []}
for i in range(len(queries)):
    text = sent_tokenize(wikipedia.page(queries[i]).content)[1]
    wiki_dict["text"].append(text)
    wiki_dict["n_words"].append(len(word_tokenize(text)))
    wiki_dict["wiki query"].append(queries[i])

wiki_df = pd.DataFrame(wiki_dict)
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words
# 0  54
# 1  16
# 2  20
# 3  24
# 4  21
# 5  17
# 6  10

# %%
# the number of rows
wiki_df["wiki query"].shape[0]
# Out:
# 7

# %% [markdown]
# Our toy corpus has six toy documents (`text` column in the dataframe) extracted from Wikipedia queries.

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.1 How many clusters?
# rubric={points}
#
#
# **Your tasks:**
#
# 1. If you are asked to cluster the documents from this toy corpus manually, how many clusters would you identify and how would you label each cluster?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.1
#
# </div>
#
# _Points:_ 1

# %% [markdown]
# 3
#
# sports <br>
# data science<br>
# foods

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.2 `KMeans` with bag-of-words representation
# rubric={points}
#
# In the lecture, we saw that data representation plays a crucial role in clustering. Changing flattened representation of images to feature vectors extracted from pre-trained models greatly improved the quality of clustering.
#
# What kind of representation is suitable for text data? We have used bag-of-words representation to numerically encode text data before, where each document is represented with a vector of word frequencies.
#
# Let's try clustering documents with this simplistic representation.
#
# **Your tasks:**
#
# 1. Create bag-of-words representation using [`CountVectorizer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) with default arguments for the `text` column in `wiki_df` above.
# 2. Cluster the encoded documents with [`KMeans` clustering](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html). Use `random_state=42` (for reproducibility) and set `n_clusters` to the number you identified in the previous exercise.
# 3. Store the clustering labels in `kmeans_bow_labels` variable below.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.2
#
# </div>
#
# _Points:_ 4

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

countVec = CountVectorizer()
bow_matrix = countVec.fit_transform(wiki_df["text"])
kmeans = KMeans(n_clusters = 3, random_state = 42)
bow_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 114 stored elements and shape (7, 94)>

# %%
bow_kmeans = kmeans.fit_predict(bow_matrix)

# %%
wiki_df["bow_kmeans"] = bow_kmeans
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words  bow_kmeans
# 0  54       2
# 1  16       0
# 2  20       0
# 3  24       0
# 4  21       1
# 5  17       0
# 6  10       0

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.3 Sentence embedding representation
# rubric={points}
#
# Bag-of-words representation is limited in that it does not take into account word ordering and context. There are other richer and more expressive representations of text which can be extracted using transfer learning. In this lab, we will use one such representation called sentence embedding representation, which uses deep learning models to generate dense, fixed-length vector representations for sentences. We will extract such representations using sentence transformer package. Sentence embedding takes into account context of words and semantic meaning of sentences and it is likely to work better when we are interested in clustering sentences based on their semantic similarity.
#
# ```
# conda activate cpsc330
# conda install pytorch::pytorch torchvision torchaudio -c pytorch
# conda install -c conda-forge sentence-transformers
# ```
#
# **Your tasks:**
#
# 1. Run the code below to create sentence embedding representation of documents in our toy corpus.
# 2. Cluster documents in our toy corpus encoded with this representation (`emb_sents`) and `KMeans` with following arguments:
#     - `random_state=42` (for reproducibility)
#     - `n_clusters`=the number of clusters you identified in 1.1
# 3. Store the clustering labels in `kmeans_emb_labels` variable below.

# %%
from sentence_transformers import SentenceTransformer

embedder = SentenceTransformer("paraphrase-distilroberta-base-v1")

# If this cell gives an error, try updating transformers with
# pip install transformers -U

# %%
emb_sents = embedder.encode(wiki_df["text"])
emb_sent_df = pd.DataFrame(emb_sents, index=wiki_df.index)
emb_sent_df
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000693  0.295712  0.101010 -0.036998 -0.143787  0.150098  0.047676
# 1 -0.202058  0.320748  0.190346  0.232200  0.600542  0.376622 -0.018205
# 2 -0.056684  0.222303  0.048026  0.053724  0.304124  0.396495 -0.000865
# 3  0.270839  0.187923 -0.010779  0.318688 -0.092012 -0.204805  0.038100
# 4 -0.101732 -0.185133 -0.107289  0.148192  0.458463 -0.555427 -0.073999
# 5  0.124749  0.327760  0.287335 -0.108245  0.024023 -0.123068  0.256753
# 6  0.108902  0.087364  0.119847 -0.050133  0.240211 -0.082101  0.190988
#
#           7         8         9  ...       758       759       760       761  \
# 0 -0.037659 -0.012557 -0.135149  ...  0.209796  0.066315  0.192004 -0.208439
# 1 -0.027148 -0.076679  0.381883  ...  0.213061 -0.080009  0.422756  0.072725
# 2 -0.261328  0.180089  0.177298  ...  0.343994 -0.412435 -0.010878  0.022342
# 3 -0.117648  0.084057 -0.170613  ...  0.069944 -0.222987  0.092472  0.309445
# 4  0.001754 -0.172459 -0.072560  ...  0.428589 -0.340837 -0.159756  0.388600
# 5 -0.186897  0.207025  0.225442  ...  0.476355 -0.425227  0.153235  0.176923
# 6  0.436203 -0.085558 -0.012788  ...  0.145414  0.160032  0.071930  0.147640
#
#         762       763       764       765       766       767
# 0 -0.174074  0.048892 -0.494627  0.100554  0.081855 -0.125856
# 1  0.016025 -0.014596 -0.202858 -0.162947 -0.190418 -0.002013
# 2  0.371978  0.108194  0.385293  0.147794 -0.077855  0.222679
# 3  0.289248  0.021022 -0.032694 -0.624040  0.358924 -0.034093
# 4  0.316263  0.090864 -0.162353 -0.225394  0.417017 -0.179008
# 5  0.036420  0.104009 -0.137497  0.265884  0.431444  0.173652
# 6  0.043789  0.253031 -0.009357  0.415206  0.142142  0.130365
#
# [7 rows x 768 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.3
#
# </div>
#
# _Points:_ 3

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit_predict(emb_sent_df)
# Out:
# array([2, 2, 0, 1, 1, 1, 1], dtype=int32)

# %%
kmeans_emb_labels = kmeans.fit_predict(emb_sent_df)

# %%
wiki_df["emb_kmeans"] = kmeans_emb_labels
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words  bow_kmeans  emb_kmeans
# 0  54       2           2
# 1  16       0           2
# 2  20       0           0
# 3  24       0           1
# 4  21       1           1
# 5  17       0           1
# 6  10       0           1

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.4 DBSCAN with cosine distance
# rubric={points}
#
# Now try [`DBSCAN`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html) on our toy dataset. K-Means is kind of bound to the Euclidean distance because it is based on the notion of means. With `DBSCAN` we can try different distance metrics. In the context of text data, [cosine similarities](https://scikit-learn.org/stable/modules/metrics.html#cosine-similarity) or cosine distances tend to work well. Given vectors $u$ and $v$, the **cosine distance** between the vectors is defined as:
#
# $$distance_{cosine}(u,v) = 1 - (\frac{u \cdot v}{\left\lVert u\right\rVert_2 \left\lVert v\right\rVert_2})$$
#
#
# **Your tasks**
#
# 1. Cluster documents in our toy corpus encoded with sentence embedding representation (`emb_sents`) and [DBSCAN](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html?highlight=dbscan#sklearn.cluster.DBSCAN) with `metric='cosine'`. You will have to set appropriate values for the hyperparamters `eps` and `min_samples` to get meaningful clusters, as default values of these hyperparameters are unlikely to work well on this toy dataset.
# 2. Store the clustering labels in the `dbscan_emb_labels` variable below.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.4
#
# </div>
#
# _Points:_ 4

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan1 = DBSCAN(eps=0.1, min_samples=1, metric='cosine')
dbscan_emb_labels1 = dbscan1.fit_predict(emb_sents)
wiki_df["emb_dbscan"] = dbscan_emb_labels1
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words  bow_kmeans  emb_kmeans  emb_dbscan
# 0  54       2           2           0
# 1  16       0           2           1
# 2  20       0           0           2
# 3  24       0           1           3
# 4  21       1           1           4
# 5  17       0           1           5
# 6  10       0           1           6

# %%
dbscan2 = DBSCAN(eps=0.01, min_samples=1, metric='cosine')
dbscan_emb_labels2 = dbscan2.fit_predict(emb_sents)
wiki_df["emb_dbscan"] = dbscan_emb_labels2
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words  bow_kmeans  emb_kmeans  emb_dbscan
# 0  54       2           2           0
# 1  16       0           2           1
# 2  20       0           0           2
# 3  24       0           1           3
# 4  21       1           1           4
# 5  17       0           1           5
# 6  10       0           1           6

# %%
dbscan3 = DBSCAN(eps=0.01, min_samples=2, metric='cosine')
dbscan_emb_labels3 = dbscan3.fit_predict(emb_sents)
wiki_df["emb_dbscan"] = dbscan_emb_labels3
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words  bow_kmeans  emb_kmeans  emb_dbscan
# 0  54       2           2          -1
# 1  16       0           2          -1
# 2  20       0           0          -1
# 3  24       0           1          -1
# 4  21       1           1          -1
# 5  17       0           1          -1
# 6  10       0           1          -1

# %%
dbscan4 = DBSCAN(eps=0.7, min_samples=2, metric='cosine')
dbscan_emb_labels4 = dbscan4.fit_predict(emb_sents)
wiki_df["emb_dbscan"] = dbscan_emb_labels4
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words  bow_kmeans  emb_kmeans  emb_dbscan
# 0  54       2           2          -1
# 1  16       0           2          -1
# 2  20       0           0          -1
# 3  24       0           1          -1
# 4  21       1           1           0
# 5  17       0           1          -1
# 6  10       0           1           0

# %%
dbscan_emb_labels = dbscan4.fit_predict(emb_sents)
dbscan_emb_labels
# Out:
# array([-1, -1, -1, -1,  0, -1,  0])

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.5 Hierarchical clustering with sentence embedding representation
# rubric={points}
#
# **Your tasks:**
#
# Try hierarchical clustering on `emb_sents`. In particular
# 1. Create and show a dendrogram with `complete` linkage and `metric='cosine'` on this toy dataset.
# 2. Create flat clusters using `fcluster` with appropriate hyperparameters and store cluster labels to `hier_emb_labels` variable below.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.5
#
# </div>
#
# _Points:_ 3

# %%
from scipy.cluster.hierarchy import (
    average,
    complete,
    dendrogram,
    fcluster,
    single,
    ward,
    linkage,
)
from scipy.cluster.hierarchy import fcluster

# %%
linkage_matrix = complete(emb_sents)
linkage_matrix
# Out:
# array([[ 4.        ,  6.        ,  7.71681671,  2.        ],
#        [ 3.        ,  7.        ,  7.9049572 ,  3.        ],
#        [ 0.        ,  1.        ,  8.17099347,  2.        ],
#        [ 5.        ,  8.        ,  8.28755805,  4.        ],
#        [ 2.        , 10.        ,  9.08579964,  5.        ],
#        [ 9.        , 11.        ,  9.79777858,  7.        ]])

# %%
from scipy.cluster.hierarchy import dendrogram

dendrogram(linkage_matrix, p=10,truncate_mode="level", color_threshold=3)
plt.xlabel("Sample index")
plt.ylabel("Cluster distance");

# %%
# flattening the dendrogram based on maximum number of clusters. 
hier_labels = fcluster(linkage_matrix, 3, criterion="maxclust") 
hier_labels
# Out:
# array([1, 1, 3, 2, 2, 2, 2], dtype=int32)

# %%
hier_emb_labels = hier_labels

# %%
# hier_emb_labels = fcluster(Z, 3, criterion="maxclust") # alternative solution

# %%
wiki_df["emb_hierarchical"] = hier_emb_labels
wiki_df
# Out:
#           wiki query  \
# 0  baguette food
# 1  banana bread food
# 2  bread food
# 3  data science
# 4  sports analytics
# 5  football sport
# 6  ice hockey
#
#                                                                                                                                                                                                                                                                         text  \
# 0  In 1986, it was established as a subsidiary of Shani Co., Ltd., and opened the first 'Paris Baguette' in Gwanghwamun, Seoul, and the first high-end bakery 'Paris Croissant' in Itaewon the following year, and the corporate name changed to the same as the brand name.
# 1  It is often a moist and sweet quick bread but some recipes are yeast raised.
# 2  Throughout recorded history and around the world, it has been an important part of many cultures' diets.
# 3  Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).
# 4  The term "sports analytics" was popularized in mainstream sports culture following the release of the 2011 film Moneyball.
# 5  Often competitive and organized, sports use, maintain, or improve physical ability and skills.
# 6  It belongs to a family of sports called hockey.
#
#    n_words  bow_kmeans  emb_kmeans  emb_dbscan  emb_hierarchical
# 0  54       2           2          -1           1
# 1  16       0           2          -1           1
# 2  20       0           0          -1           3
# 3  24       0           1          -1           2
# 4  21       1           1           0           2
# 5  17       0           1          -1           2
# 6  10       0           1           0           2

# %% [markdown]
# #### <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.6 Discussion
# rubric={points}
#
# **Your tasks:**
#
# 1. Reflect on and discuss the clustering results of the methods you explored in the previous exercises, focusing on the following points:
#     - effect of input representation on clustering results
#     - whether the clustering results match with your intuitions and the challenges associated with getting the desired clustering results with each method

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.6
#
# </div>
#
# _Points:_ 4

# %% [raw]
# BOW: represents word data in numbers(as sparse matrix) based on its frequency and we fit a clustering method on the sparse matrix
# Sentence Embedding: represents word data in numbers in a way that captures the meaning of sentence rather than how many times each word appear in the data
# ---------------------------------------------------------------------------------------
# bow_kmean:
# cluster0: bread food
# cluster1: baguette food/ data science/sports analytics/ football/ sport/ ice hockey
# cluster2: banana bread food
# emb_kmean:
# cluster0: bread food
# cluster1: data science/sports analytics/ football/ sport/ ice hockey
# cluster2: banana bread food/ baguette food
# ---------------------------------------------------------------------------------------
# Embedded sentence representation captures the meaning of the sentence rather than its frequency. so emb_kmean has better classification for cluster2 including banana bread and baguette together.
# Both representation groups sports and data science together which is probably because of the lack of data sample for data science group.
# ---------------------------------------------------------------------------------------

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.7 Visualizing clusters
# rubric={points:4}
#
#
# One approach to working with unlabeled data is visualization. That said, our data is high-dimensional, making it challenging to visualize. Take sentence embedding representation as an example: each instance is depicted in 768 dimensions. To visualize such high-dimensional data, we can employ dimensionality reduction techniques to extract the most significant 2 or 3 components, and then visualize this low-dimensional data.
#
# Given data as a `numpy` array and corresponding cluster assignments, the `plot_umap_clusters` function below transforms the data by applying dimensionality reduction technique called [UMAP](https://umap-learn.readthedocs.io/en/latest/) to it and plots the transformed data with different colours for different clusters.
#
# > *Note: At this point we are using this function only for visualization and you are not expected to understand the UMAP part.*
#
# You'll have to install the `umap-learn` package in the course conda environment either with `conda` or `pip`, as described in the [documentation](https://umap-learn.readthedocs.io/en/latest/index.html).
#
# ```
# > conda activate cpsc330
# > conda install -c conda-forge umap-learn
# ```
# or
#
# ```
# > conda activate cpsc330
# > pip install umap-learn
# ```
#
# If you get an error with the import below try
#
# ```
# pip install --upgrade numba umap-learn
# ```
#
# **Your tasks:**
#
# 1. Visualize the clusters created by the methods above using `plot_umap_clusters` function below. In other words, visualize clusters identified by each of the methods below.
#     - K-Means with bag-of-words representation
#     - K-Means with sentence embedding representation
#     - DBSCAN with sentence embedding representation
#     - Flat cluster of hierarchical clustering with sentence embedding representation

# %%
import umap

# %%
# Removes umap warnings due to a change of API in sklearn.
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

def plot_umap_clusters(
    data,
    cluster_labels,
    raw_sents=wiki_df["text"],
    show_labels=False,
    size=50,
    n_neighbors=15,
    title="UMAP visualization",
    ignore_noise=False,
):
    """
    Carry out dimensionality reduction using UMAP and plot 2-dimensional clusters.

    Parameters
    -----------
    data : numpy array
        data as a numpy array
    cluster_labels : list
        cluster labels for each row in the dataset
    raw_sents : list
        the original raw sentences for labeling datapoints
    show_labels : boolean
        whether you want to show labels for points or not (default: False)
    size : int
        size of points in the scatterplot
    n_neighbors : int
        n_neighbors hyperparameter of UMAP. See the documentation.
    title : str
        title for the visualization plot

    Returns
    -----------
    None. Shows the clusters.
    """

    reducer = umap.UMAP(n_neighbors=n_neighbors, random_state=42, n_jobs=1)
    Z = reducer.fit_transform(data)  # reduce dimensionality
    umap_df = pd.DataFrame(data=Z, columns=["dim1", "dim2"])
    umap_df["cluster"] = cluster_labels

    if ignore_noise:
        umap_df = umap_df[umap_df["cluster"] != -1]

    labels = np.unique(umap_df["cluster"])

    fig, ax = plt.subplots(figsize=(6, 5))
    ax.set_title(title)

    scatter = ax.scatter(
        umap_df["dim1"],
        umap_df["dim2"],
        c=umap_df["cluster"],
        cmap="tab20b",
        s=size,
        #edgecolors="k",
        #linewidths=0.1,
    )

    legend = ax.legend(*scatter.legend_elements(), loc="best", title="Clusters")
    ax.add_artist(legend)

    if show_labels:
        x = umap_df["dim1"].tolist()
        y = umap_df["dim2"].tolist()
        for i, txt in enumerate(raw_sents):
            ax.annotate(" ".join(txt.split()[:10]), (x[i], y[i]))
    plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.7
#
# </div>
#
# _Points:_ 4

# %%
bow_kmeans=wiki_df[["bow_kmeans"]].to_numpy()
emb_kmeans=wiki_df[["emb_kmeans"]].to_numpy()
emb_dbscan=wiki_df[["emb_dbscan"]].to_numpy()
emb_hierarchical=wiki_df[["emb_hierarchical"]].to_numpy()

# %%
# bow_kmeans, kmeans_emb_labels, dbscan_emb_labels, hier_emb_labels are one column numpy array 
# that contains predicted clustering labels

plot_umap_clusters(data=bow_kmeans, cluster_labels=bow_kmeans, size=100, title="K-Means (Bag-of-Words)",n_neighbors=4)

plot_umap_clusters(data=emb_kmeans, cluster_labels=kmeans_emb_labels,size=100, title="K-Means (Sentence Embedding)", n_neighbors=3)

plot_umap_clusters(data=emb_dbscan, cluster_labels=dbscan_emb_labels,size=100, title="DBSCAN (Sentence Embedding)",n_neighbors=3)

plot_umap_clusters(data=emb_hierarchical, cluster_labels=hier_emb_labels,size=100, title="Hierarchical Clustering (Sentence Embedding)",n_neighbors=4)

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# ## Exercise 2: [Food.com](https://www.food.com/) recipes
# <hr>
#
# Now that we have applied document clustering on a toy corpus, let's move to a more realistic corpus.
#
# In the lecture, we worked on an activity of manually clustering food items and discussed challenges associated with it. We also applied different clustering algorithms to cluster food images. We'll continue this theme of clustering food items in this lab. But instead of images we will cluster textual description of food items, i.e., recipe names.
#
# In this lab, we will work with a sample of [Kaggle's Food.com recipes corpus](https://www.kaggle.com/shuyangli94/food-com-recipes-and-user-interactions). This corpus contains 180K+ recipes and 700K+ recipe reviews. In this lab, we'll only focus on recipes and **not** on reviews. The recipes are present in `RAW_recipes.csv`. Our goal is to find categories or groupings of recipes from this corpus based on their names.
#
# **Your tasks:**
#
# - Download [`RAW_recipes.csv`](https://www.kaggle.com/shuyangli94/food-com-recipes-and-user-interactions?select=RAW_recipes.csv) and put it under the `data` directory in the homework folder.
# - Run the code below. The dataset is quite large, and in this assignment, for speed, you will work with a sample of the dataset. The function `get_recipes_sample` below carries out some preliminary preprocessing and returns a sample of the recipes with most frequent tags.
#
# > *Note: Depending upon the capacity of your computer, feel free to increase or decrease the size of this sample by changing the value for `n_tags`. If you decide to go with a different value of `n_tags`, state it clearly in Exercise 2.1 so that the grader knows about it.*

# %%
orig_recipes_df = pd.read_csv("data/RAW_recipes.csv")
orig_recipes_df.shape
# Out:
# (231637, 12)

# %%
def get_recipes_sample(orig_recipes_df, n_tags=300, min_len=5):
    orig_recipes_df = orig_recipes_df.dropna()  # Remove rows with NaNs.
    orig_recipes_df = orig_recipes_df.drop_duplicates(
        "name"
    )  # Remove rows with duplicate names.
    # Remove rows where recipe names are too short (< 5 characters).
    orig_recipes_df = orig_recipes_df[orig_recipes_df["name"].apply(len) >= min_len]
    # Only consider the rows where tags are one of the most frequent n tags.
    first_n = orig_recipes_df["tags"].value_counts()[0:n_tags].index.tolist()
    recipes_df = orig_recipes_df[orig_recipes_df["tags"].isin(first_n)]
    return recipes_df

# %%
recipes_df = get_recipes_sample(orig_recipes_df)
recipes_df.shape
# Out:
# (9100, 12)

# %%
#recipes_df

# %%
recipes_df["name"]
# Out:
# 42        i yam what i yam  muffins
# 101       to your health  muffins
# 129       250 00 chocolate chip cookies
# 138       lplermagronen
# 163       california roll   salad
#                    ...
# 231430    zucchini wheat germ cookies
# 231514    zucchini blueberry bread
# 231547    zucchini salsa burgers
# 231596    zuppa toscana
# 231629    zydeco salad
# Name: name, Length: 9100, dtype: object

# %% [markdown]
# <br><br>

# %% [markdown]
# **In the rest of the homework, we will use `recipes_df` above, which is a subset of the original dataset.**

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 2.1 Longest and shorter recipe names
# rubric={points:2}
#
# **Your tasks:**
#
# 1. Print the shortest and longest recipe names (length in terms of number of characters) from `recipes_df`. If there is more than one recipe with the same shortest/longest length, store **one** of them in `shortest_recipe` and/or `longest_recipe` as a **string**.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.1
#
# </div>
#
# _Points:_ 2

# %%
shortest_recipe = recipes_df.loc[recipes_df["name"].apply(len).idxmin(), "name"]
longest_recipe = recipes_df.loc[recipes_df["name"].apply(len).idxmax(), "name"]

print(shortest_recipe)
print(longest_recipe)
# Out:
# bread
# baked tomatoes with a parmesan cheese crust and balsamic drizzle

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 2.2 More EDA
# rubric={points:2}
#
# **Your tasks:**
# 1. Create a word cloud for the recipe names. You can use [the `wordcloud` package](https://github.com/amueller/word_cloud) for this, which you will have to install in the course environment.
# ```
# > conda activate cpsc330
# > conda install -c conda-forge wordcloud
# ```

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.2
#
# </div>
#
# _Points:_ 2

# %%
from wordcloud import WordCloud

# Combine all recipe names into one large string, from all rows
text = " ".join(recipes_df["name"])

wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # Hide the axes
plt.title("Word Cloud of Recipe Names")
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 2.3 Representing recipe names
# rubric={points:3}
#
# The next step is creating a representation of recipe names.
#
# **Your tasks:**
#
# 1. Similar to Exercise 1, create sentence embedding representation of recipe names (`name` column in `recipes_df`).  For the rest of the homework, we'll stick to the sentence embedding representation of recipe names.
#
#
# > You might have to convert the recipe names to a list (`recipes_df["name"].tolist()`) for the embedder to work
# > *If you create a dataframe with sentence embedding representation, set the index to `recipes_df.index` so that the indices match with the indices of the sample we are working with.*
# > **This might take a while to run.**

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.3
#
# </div>
#
# _Points:_ 3

# %%
embedder = SentenceTransformer("paraphrase-distilroberta-base-v1")

# %%
embedded_names=embedder.encode(recipes_df["name"].tolist())

# %%
embedded_names_df = pd.DataFrame(embedded_names, index=recipes_df.index)

# %%
embeddings = embedded_names_df

# %%
embeddings
# Out:
#                0         1         2         3         4         5         6  \
# 42     -0.333475  0.227865 -0.307339  0.410549  0.917104 -0.345507  0.305810
# 101    -0.024523  0.246222 -0.055709  0.358273  0.454786 -0.088055  0.260368
# 129    -0.026562  0.194671  0.038102 -0.099181  0.653784 -0.230868  0.064517
# 138    -0.168001 -0.219218  0.330761  0.302196 -0.173169  0.204557  0.192390
# 163     0.061076 -0.333799  0.242906  0.395978 -0.466468  0.496505 -0.136754
# ...          ...       ...       ...       ...       ...       ...       ...
# 231430 -0.009714  0.200162  0.018329  0.237817  0.748988  0.121918  0.087918
# 231514 -0.106532 -0.034574  0.160070  0.258504  0.882480  0.091899  0.008815
# 231547  0.016149 -0.053036 -0.035098 -0.021836  0.735160  0.245519 -0.151837
# 231596  0.026659  0.202483  0.344634 -0.138708  0.514423  0.630948 -0.003165
# 231629 -0.031947 -0.258190 -0.079766 -0.507932 -0.155580  0.635224 -0.127390
#
#                7         8         9  ...       758       759       760  \
# 42      0.256676 -0.147711  0.040727  ... -0.053024 -0.209463  0.362419
# 101     0.231947  0.093013 -0.007835  ...  0.144861 -0.435459  0.208344
# 129     0.001376 -0.061281  0.232094  ...  0.169605  0.239355  0.392649
# 138     0.140975  0.303174  0.038063  ...  0.019094 -0.002448  0.437832
# 163     0.122097  0.114249  0.065318  ...  0.044438 -0.213657  0.410353
# ...          ...       ...       ...  ...       ...       ...       ...
# 231430  0.216755 -0.291040  0.074165  ... -0.120458  0.162878  0.480063
# 231514  0.372013 -0.266541  0.085018  ...  0.063240 -0.099132  0.332694
# 231547  0.003954  0.102567  0.001362  ...  0.102296  0.023821  0.602684
# 231596 -0.102897 -0.434900 -0.192056  ... -0.162457  0.130695  0.113645
# 231629  0.062608  0.146173 -0.004416  ...  0.043947 -0.066851  0.167460
#
#              761       762       763       764       765       766       767
# 42     -0.246086  0.208379 -0.024874  0.506562  0.197738 -0.386422 -0.002184
# 101    -0.002655 -0.081200 -0.130489  0.452378  0.186310 -0.278500  0.028581
# 129     0.271397 -0.093971  0.060101 -0.281417  0.133210 -0.122344 -0.109863
# 138     0.563785  0.033442  0.187658  0.529251 -0.233786  0.509931  0.410715
# 163    -0.233599 -0.224422  0.094331  0.173351  0.105782 -0.114749 -0.150677
# ...          ...       ...       ...       ...       ...       ...       ...
# 231430  0.235902  0.146278  0.252980 -0.063640 -0.066044 -0.133067 -0.034039
# 231514  0.031868  0.582795  0.216874  0.241107  0.091759 -0.261551 -0.082310
# 231547 -0.067071  0.177534  0.253982  0.242440 -0.436002 -0.053909  0.012423
# 231596  0.186650 -0.155393  0.130507  1.146238 -0.240861  0.236831  0.177123
# 231629 -0.087434 -0.097305  0.265510 -0.099823 -0.569382 -0.219148 -0.033524
#
# [9100 rows x 768 columns]

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# ## Exercise 3: Clustering recipe names
# <hr>
#
# In this exercise you'll cluster recipe names with some of the clustering algorithms we have seen in class. This will also involve making some attempts to pick reasonable hyperparameter values for each clustering method based on the quality of the resulting clusters. For example, for KMeans, you need to specify the number of clusters in advance, which is often challenging on real-world datasets. For DBSCAN, you need to pick appropriate `eps` and `min_samples`. For hierarchical clustering, you need to pick a suitable linkage criterion, distance metric, and prune the tree so that it's possible to visualize and interpret it.
#
# Here are some methods which may help you with picking reasonable values for the hyperparameters.
# - Visualize the Elbow plot (KMeans).
# - Visualize Silhouette plots.
# - Visualize resulting clusters using `plot_umap_clusters` function from Exercise 1.
# - Sample some recipes from each cluster, manually inspect whether there are coherent semantic themes. (For this, you may use the function `print_clusters` given below.)
#
# > You may use the [`yellowbrick`](https://www.scikit-yb.org/en/latest/) package for visualizing the Elbow plot and the Silhouette plots. You can intall it with
#
# ```conda install -c districtdatalabs yellowbrick```
#
# **Note that the process of picking reasonable hyperparameter values will be exploratory, iterative, and will involve manual inspection and judgment, as there is no ground truth to verify how well the model is doing. In your solutions, please do not include everything you try. Only present the results of the most informative trials. Add a narrative to your answer so that it's easy for the grader to follow your choices and reasoning.**

# %%
def print_clusters(recipes_df, cluster_labels, n_recipes=10, replace=False, random_state=None):
    """
    Given recipes_df containing recipe names and cluster assignment (labels), 
    sample and print n_recipes recipes per cluster. 

    Parameters
    -----------
    recipe_df : pandas dataframe 
        recipes dataframe containing recipe names in the "name" column
    cluster_labels : ndarray or a list
        cluster labels for each row in recipes_df 
    n_recipes : int
        number of examples to sample from each cluster
    replace: bool
        replace flag to pass to the sampling of recipe names

    Returns
    -----------
    None
    """    
    
    grouped = (
        pd.DataFrame(
            {
                "name": recipes_df["name"],
                "cluster_label": cluster_labels,
            }
        )
        .sort_values("cluster_label")
        .groupby("cluster_label")    
    )
    
    for name, group in grouped:
        print(f"Cluster {name}")        
        print(("----------").format(""))        
        print("\n".join(group.sample(n_recipes, random_state=random_state)['name'].tolist()))
        print("\n\n")

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.1 K-Means
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Cluster recipe titles using KMeans. Make some attempts to determine the optimal number of clusters.
# 2. Pick one or two best models and justify your choice.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.1
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
from yellowbrick.cluster import KElbowVisualizer
from yellowbrick.cluster import SilhouetteVisualizer

# %%
kmean_recipes = KMeans(random_state=42)
visualizer_elb = KElbowVisualizer(kmean_recipes, k=(2, 20), metric='distortion', timings=False)

# %%
visualizer_elb.fit(embeddings)
visualizer_elb.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans_6_clusters = KMeans(n_clusters=6, random_state=42)

# %%
visualizer_sil = SilhouetteVisualizer(kmeans_6_clusters)  
visualizer_sil.fit(embeddings)  
visualizer_sil.show()
# Out:
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 9100 Samples in 6 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
kmeans_labels_6 = kmeans_6_clusters.fit_predict(embeddings)
plot_umap_clusters(embeddings, kmeans_labels_6)

# %%
print_clusters(recipes_df, kmeans_labels_6)
# Out:
# Cluster 0
# ----------
# apple curry chicken
# chicken marbella   silver palate cookbook
# heloises olive nut sandwich spread
# skillet taco mac n cheese
# pumpkin seed  pepita  salsa
# barbecue style stuffed green peppers
# mediterranean pita pizzas
# salisbury steaks deluxe
# barley butternut squash pilaf
# karen s chicken and white sauce
#
#
#
# Cluster 1
# ----------
# four layer lemon cake
# chocolate ginger cake with bourbon sauce
# wiltshire white cake
# lemon amaretto bundt cake
# granny cake
# heavenly white cake
# coconut mocha cake
# sourdough carrot cake
# bahama mama banana rum cake
# pumpkin cheesecake cpk
#
#
#
# Cluster 2
# ----------
# santorini cocktail
# manhandler
# tom s coffee cream martini
# african lullaby
# traditional pico de gallo
# angel food torte
# king arthur flour s faux reos
# spam supreme
# fritatta
# chambord walk
#
#
#
# Cluster 3
# ----------
# tuscan bean and onion salad
# orange mustard dressing
# spinach and tangerine salad
# cheesecake factory chopped salad
# annie s spinach salad
# citrus cumin salad dressing
# 4 ingredient tomato  cucumber   onion salad
# cherry tomato salad with blue cheese
# jacob s salad
# strawberry romaine salad
#
#
#
# Cluster 4
# ----------
# praline crunch cups
# caramel coffee indulgence
# pumpkin banana bread
# i yam what i yam  muffins
# healthier banana bread
# jean s special berry pie
# chocolate fried pies
# sour cream  blueberry waffles
# custardy french toast
# jam filled almond muffins
#
#
#
# Cluster 5
# ----------
# carmel apple cider cookies
# chewiest ever chocolate y chip ity cookies
# raspberry dream cookies
# cookie   candy penguins
# melt in your mouth cookies
# triple chip cookies
# sugar free maple cookies
# summertime tea cookies
# fabulous cut out cookies
# sugar cookie perfection

# %% [raw]
# K=6 (elbowmethods optimal) captures overall pattern of recipe name quite well, just to explore a bit more I will try some different Ks that are greater and smaller than 6

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %% [markdown]
# <h1>K=5</h1>

# %%
kmeans_5_clusters = KMeans(n_clusters=5, random_state=42)

# %%
visualizer_sil = SilhouetteVisualizer(kmeans_5_clusters)  
visualizer_sil.fit(embeddings)  
visualizer_sil.show()
# Out:
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 9100 Samples in 5 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
kmeans_labels_5 = kmeans_5_clusters.fit_predict(embeddings)
plot_umap_clusters(embeddings, kmeans_labels_5)

# %%
print_clusters(recipes_df, kmeans_labels_5)
# Out:
# Cluster 0
# ----------
# best ever potatoes
# chicken fried steak and gravy
# fire and iceberg salad
# feastive tossed salad
# authentic southern fried okra
# creamy chicken fusilli
# lime chicken enchiladas
# lemon chicken bites
# greek herb rub for fish
# ultimate vegan chili
#
#
#
# Cluster 1
# ----------
# white chocolate cheesecake with triple raspberry
# coconut coffee liqueur cake
# queen elizabeth cake
# calamondin cake
# rainbow citrus cake
# bananas  n cream bundt cake
# cinnamon walnut bundt cake
# chocolate cherry bomb
# yellow cake for strawberries and whipped cream
# rum cake
#
#
#
# Cluster 2
# ----------
# nutella lava cookies
# oatmeal raisin bran cookies
# easy bake oven butter cookies
# chewy ginger cookies
# cream cheese bar cookies
# white chocolate   cranberry  oatmeal   walnut cookies
# chocolate caramel dream cookies
# pumpkin waffle cookie treats
# cinnamon chip oatmeal cookies
# peanut butter devil cookies
#
#
#
# Cluster 3
# ----------
# dark n  stormy
# southern  road house bbq
# lillet sin
# caribbean cassis
# moroccan mint tea
# bronze dragon
# olive rice
# electric smurf
# heaven so sweet
# macaroon martini
#
#
#
# Cluster 4
# ----------
# yummy fruit muffins
# granny s coconut pie
# cherry yogurt muffins
# tender sour cream sweet dough
# brazilian cheese puffs   pao de queijo  gluten free
# banana walnut and date loaf
# magic peanut butter middles
# secret ingredient  brownie
# fudgy brownie pie
# mimi s lemon poppy seed muffins

# %% [raw]
# I picked K=5 because decreasing K around K=1~6 would sharply increase the variance according to Elbowmethod plot

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %% [markdown]
# <h1>K=10</h1>

# %%
kmeans_10_clusters = KMeans(n_clusters=10, random_state=42)

# %%
visualizer_sil = SilhouetteVisualizer(kmeans_10_clusters)  
visualizer_sil.fit(embeddings)  
visualizer_sil.show()
# Out:
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 9100 Samples in 10 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
kmeans_labels_10 = kmeans_10_clusters.fit_predict(embeddings)
plot_umap_clusters(embeddings, kmeans_labels_10)

# %%
print_clusters(recipes_df, kmeans_labels_10)
# Out:
# Cluster 0
# ----------
# pink russian
# tomato bredie
# onion lover s twist
# lemonade concentrate
# sonny s steak hoagies
# everyday living lemon squares
# shrimp po boy
# el ritual
# salmon patties  hints from heloise
# the dingo
#
#
#
# Cluster 1
# ----------
# chocolate swirl marble pound cake
# supreme strawberry cake
# cocoa almond coco cake
# mango mousse cake
# vanilla butternut pound cake with maraschino cherries
# homemade funfetti cupcakes
# gelatin poke cake
# caramel pineapple upside down cake
# danish dessert cake     mignon s recipe   sarah
# almond cream cheese pound cake
#
#
#
# Cluster 2
# ----------
# breakfast at tiffany s
# marinated coleslaw
# tyler florence s shrimp scampi with linguine
# pollo alla cacciatora
# lady gogdiva martini
# whole matzo matzo balls
# bellini tini
# torta barozzi
# mexican burrito pie
# tacos de papa  fried potato tacos
#
#
#
# Cluster 3
# ----------
# hazelnut pumpkin pie
# gingerbread pancakes w  fresh blueberry syrup
# banana banana nut bread
# pass that sweet potato pie
# flavoured rice pudding you say
# navajo style peach crisp
# cranberry and strawberry sangria
# green onion and cream cheese muffins
# authentic indian taco fry bread
# strawberry macadamia nut muffins
#
#
#
# Cluster 4
# ----------
# coconut chocolate chip cookies
# ghirardelli macadamia white chocolate chip cookies
# martha stewart s cowboy cookies
# toffee bits cookies
# tropical mango cookies
# sugar cookie perfection
# cookie spreads   coffee chocolate macadamia
# harvey s ranger cookies
# old fashioned sour cream sugar cookies
# honey roasted peanut butter toffee swirl cookies
#
#
#
# Cluster 5
# ----------
# goat cheese  greens  and walnut salad
# salt and vinegar potato salad
# date   fig salad dressing
# homemade ranch dressing recipe
# avocado olive salad
# fennel salad with citrus zests and toasted pine nuts
# waldorf salad on the lighter side
# marra s light citrus buttermilk salad dressing
# green jacket salad dressing
# fire and iceberg salad
#
#
#
# Cluster 6
# ----------
# magical low calorie margarita
# butterbeer  alcoholic
# blizzard martini
# coconut margaritas
# sarah palins barracuda cocktail
# butterscotch mudslide shake
# windex martini
# class act cocktail
# cranberry cosmopolitan
# tropicana cocktail
#
#
#
# Cluster 7
# ----------
# sarasota s spaghetti sauce
# potato  tomato and cheese tart
# buca di beppo chicken cacciatore with garlic mashed potatoes
# tomato and cheese baked belly buttons  tortellini
# sauteed zucchini and arugula
# l o v e  wrap sandwich
# curried turkey wraps  great for leftovers
# snow crab dip
# special ivy inn tomato pie
# yukon gold gratin with chilies  cilantro and cheese
#
#
#
# Cluster 8
# ----------
# bacon feta stuffed chicken
# chinese pork with noodles
# uyghur laghman pulled noodle sauce
# fantastic meatloaf
# walnut chicken with lime sauce
# apple curry chicken
# indian chicken meatballs and lentil stew
# tuscan meatballs
# roasted chickpeas with chard
# crispy buttermilk chicken
#
#
#
# Cluster 9
# ----------
# snowy white chocolate scones
# blueberry lemon oreo cheesecake bars
# chocolate mint smooth
# little gems with blue cheese dressing
# screaming chocolate monkey
# applescotch crisp
# peanut butter chocolate layer bars
# chocolate cherry fudge bundt
# dutch apple pie bars
# white chocolate chambord

# %% [raw]
# K=10 starts to group chicken and alcohol together while some groups maintain reasonable separations
# Overall it still labels recipe names quite well,

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %% [markdown]
# Elbowmethod optimal was 6, which is surprizingly bad in Silhouette plot. K = 20 gives us the best silhouette coefficient values in my experiments. It seems like it could be improved by increasing the K.
# Silhouette plot score did not improved much despite the jump of k values from 5 to 20.
# I

# %%
from sklearn.decomposition import PCA

# 2D
pca = PCA(n_components=2)
embeddings_pca = pca.fit_transform(embeddings)

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(embeddings_pca[:, 0], embeddings_pca[:, 1], alpha=0.5)
plt.title("PCA Visualization (2D)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.2 DBSCAN
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Cluster recipe names using `DBSCAN` with `metric="cosine"`. Make some attempts to tune the  hyperparameters `eps` and `min_samples`.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.2
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
dbscan_7 = DBSCAN(eps=0.7, min_samples=100)
dbscan_7_labels= dbscan_7.fit_predict(embeddings)
#dbscan_7_labels

# %% [markdown]
# #visualizer_sil = SilhouetteVisualizer(dbscan_7)
# #visualizer_sil.fit(embeddings)
# #visualizer_sil.show()
# this does not work for DBSCAN

# %% [markdown]
# <h1>-----I tried to run the silhouette plot on dbscan with the lecture's code but it didn't word-----</h1>

# %% [raw]
# # Yellowbrick is designed to work with K-Means and not with DBSCAN.
# # So it needs the number of clusters stored in n_clusters
# # It also needs `predict` method to be implemented.
# # So I'm implementing it here so that we can use Yellowbrick to show Silhouette plots.
# n_clusters = len(set(dbscan_7.labels_))
# dbscan_7.n_clusters = n_clusters
# dbscan_7.predict = lambda x: dbscan_7.labels_

# %% [raw]
# visualizer_dbs_sil = SilhouetteVisualizer(dbscan_7, colors="yellowbrick")
# visualizer_dbs_sil.fit(embeddings)  # Fit the data to the visualizer
# visualizer_dbs_sil.show()

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
plot_umap_clusters(data=embeddings, cluster_labels=dbscan_7_labels, title="DBSCAN (Sentence Embedding)")

# %%
print_clusters(recipes_df, dbscan_7_labels)
# Out:
# Cluster -1
# ----------
# low sugar    low fat  lemon cheesecake
# lemongrass  lime   thai basil mojito
# kahlua   iced tea
# thai style ground turkey with chiles and basil
# simple healthy juicer
# debbie s hot german potato salad
# sour cream and chicken enchiladas
# the very easiest cookies recipe   cake mix cookies
# chocolate frosted brownies
# chili lime oven fries

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
dbscan_10 = DBSCAN(eps=0.7, min_samples=50)
dbscan_10_labels= dbscan_10.fit_predict(embeddings)
dbscan_10_labels
plot_umap_clusters(data=embeddings, cluster_labels=dbscan_10_labels, title="DBSCAN (Sentence Embedding)")

# %%
print_clusters(recipes_df, dbscan_10_labels)
# Out:
# Cluster -1
# ----------
# my meatloaf 101
# key lime cupcakes
# pumpkin walnut cookies
# tropicana cocktail
# banana walnut and date loaf
# sea breeze salad
# chewiest ever chocolate y chip ity cookies
# grandma weseman s english pea salad
# ginger apple dessert
# cibola

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
dbscan_100 = DBSCAN(eps=10, min_samples=100)
dbscan_100_labels= dbscan_100.fit_predict(embeddings)
dbscan_100_labels
plot_umap_clusters(data=embeddings, cluster_labels=dbscan_100_labels, title="DBSCAN (Sentence Embedding)")

# %%
print_clusters(recipes_df, dbscan_100_labels)
# Out:
# Cluster -1
# ----------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 print_clusters(recipes_df, dbscan_100_labels)
#
# Cell In[44], line 36, in print_clusters(recipes_df, cluster_labels, n_recipes, replace, random_state)
#      34 print(f"Cluster {name}")
#      35 print(("----------").format(""))
# ---> 36 print("\n".join(group.sample(n_recipes, random_state=random_state)['name'].tolist()))
#      37 print("\n\n")
#
# File /opt/miniconda3/envs/cpsc330/lib/python3.12/site-packages/pandas/core/generic.py:6118, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6115 if weights is not None:
#    6116     weights = sample.preprocess_weights(self, weights, axis)
# -> 6118 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119 result = self.take(sampled_indices, axis=axis)
#    6121 if ignore_index:
#
# File /opt/miniconda3/envs/cpsc330/lib/python3.12/site-packages/pandas/core/sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# File numpy/random/mtrand.pyx:1024, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
dbscan_40 = DBSCAN(eps=4, min_samples=40)
dbscan_40_labels= dbscan_40.fit_predict(embeddings)
dbscan_40_labels
plot_umap_clusters(data=embeddings, cluster_labels=dbscan_40_labels, title="DBSCAN (Sentence Embedding)")

# %%
print_clusters(recipes_df, dbscan_40_labels)
# Out:
# Cluster -1
# ----------
# barb s sauteed swiss chard
# candy bar cupcakes
# alex guarnaschelli s mother chicken with bbq
# vegetables in garlic cream sauce
# black unicorn
# peanut brittle white chocolate cookies
# country breakfast pie
# chicken with cashew nuts
# melissa s fried taunga
# cosmopolitano

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
dbscan_40 = DBSCAN(eps=6, min_samples=40)
dbscan_40_labels= dbscan_40.fit_predict(embeddings)
dbscan_40_labels
plot_umap_clusters(data=embeddings, cluster_labels=dbscan_40_labels, title="DBSCAN (Sentence Embedding)")

# %%
print_clusters(recipes_df, dbscan_40_labels)
# Out:
# Cluster -1
# ----------
# milk   cookie cups
# banana peanut butter cookies
# mujadara
# white chocolate martini   pete evans
# syrian roasted beets
# claim jumper s crunchy spinach salad
# blue velvet cocktail
# peach cosmo
# sensational coleslaw
# melissa d arabian s pulled pork

# %% [raw]
# It seems like the DBSCAN is trying to force clustering even though there is no meaning full boundary.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.3 Hierarchical clustering
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Try hierarchical clustering with `metric="cosine"` on this problem. Show a dendrogram by using a suitable truncation method.
# 2. Create flat clusters by cutting the tree at the appropriate level.
#
# > *Note: Try orientation="left" of `dendrogram` for better readability of the dendrogram.*

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.3
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
linkage_matrix = linkage(embeddings,method="complete", metric="cosine")

# %%
ax = plt.gca()
dendrogram(linkage_matrix, ax=ax, p=7, truncate_mode="lastp")
plt.ylim(1.1, 1.3)
plt.xlabel("Sample index")
plt.ylabel("Cluster distance");

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
hier_labels = fcluster(linkage_matrix, t=1.19, criterion="distance") 
hier_labels
# Out:
# array([2, 2, 2, ..., 3, 4, 3], dtype=int32)

# %%
plot_umap_clusters(embeddings, hier_labels)

# %%
print_clusters(recipes_df, hier_labels)
# Out:
# Cluster 1
# ----------
# cheese waffles with ham sauce
# spicy thai one pot
# cold shoulder
# bad attitude
# hungry girl pepperoni pizza scramble
# ranch style dip
# danish gin fizz
# dutch velvet
# sweet repeat
# gingerbread french toast
#
#
#
# Cluster 2
# ----------
# fudgy chocolate torte
# low fat lemon poppy seed cake
# cranberry orange muffins  gluten free
# rich fudge ribbon bundt cake
# chocolate fruit muffins
# caramel cream coffee
# carrot cake squares  baby food
# eggnog crepes
# yellow pudding cake with chocolate chips
# chocolate tunnel fudge cake
#
#
#
# Cluster 3
# ----------
# escargots bourguignonne
# smoothie
# fritatta
# sweet dijon vinaigrette
# old world raspberry bars
# tuna goop
# tangy lemon bars
# tequichi
# beef   cheese burritos
# black bean pinwheels
#
#
#
# Cluster 4
# ----------
# sweet   sour pork chops
# pumpkin spice crescent breakfast rolls
# spicy marinated olives
# kids  favourite salmon pasta with peas
# roasted red potatoes with shallots and fresh herbs
# morning muesli bread recipe
# barley butternut squash pilaf
# family favorite salad dressing
# zesty pan fried chicken
# sarasota s spicy grilled shrimp salad sandwich
#
#
#
# Cluster 5
# ----------
# asian slaw
# grilled vegetables with green curry marinade
# insalata caprese
# chambord vodka soda
# my version of red robin s honey mustard
# broccoli casserole  jane and michael stern
# braised to be praised paprika chicken
# kentucky slaw
# lamb and artichoke stew  greek
# charlie walkers pork chop casserole

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
hier_labels = fcluster(linkage_matrix, t=5, criterion="maxclust") 
plot_umap_clusters(embeddings, hier_labels)

# %%
print_clusters(recipes_df, hier_labels)
# Out:
# Cluster 1
# ----------
# dreamsicle creamsicle on the rocks
# dijon cheesesteak hoagies
# spicy sweet wrapped dates
# quick and easy onion rolls
# baileys kiss
# tart cherry cheddar bars
# skinny cocktails   the un rita margarita
# tiger woods cocktail
# creamy sex on the beach
# rossini cocktail
#
#
#
# Cluster 2
# ----------
# the best peanut butter brownies
# light chocolate cake
# easy bake oven secret chocolate chip cookies
# chocolate mint  brownie dessert
# chocolate dream cream dessert
# tropical mango cookies
# chocolate raisin nut crunch bars
# oatmeal cinnamon chips cookies
# wuollet s brownie enormous   minnesota brownies
# old fashion sugar cookies
#
#
#
# Cluster 3
# ----------
# lemon basil syrup  for beverages
# jet ski killer
# jean s special berry pie
# total delight
# the real cafeteria peanut butter bars
# franks in foil
# apple amaretto strudel
# old fashioned root beer float cake
# sour raspberry martini
# cheesy turnips
#
#
#
# Cluster 4
# ----------
# orange balsamic chicken
# greek style potato skins
# italian chicken   veggie soup   paula deen
# everything but the kitchen sink   pumpkin  loaf
# wolfgang puck s juicy pork chops
# heart and soul black bean soup
# marzetti noodle bake casserole
# edam and tomato chicken parcels
# boursin stuffed potatoes
# chicken corn soup
#
#
#
# Cluster 5
# ----------
# vanita s insalata verde
# the bianca pop
# oatmeal bannock  low fat
# easy marinara
# real margaritas
# pork medallions with chanterelles
# cheaters enchiladas
# pork chop scallop
# chicken noodle   dumpling soup
# burberry bulldog

# %% [markdown]
# <br>
# <h1>-------------------------------------------------------------------------------------------</h1>
# <br>

# %%
hier_labels = fcluster(linkage_matrix, t=1.225, criterion="distance") 
plot_umap_clusters(embeddings, hier_labels)

# %%
print_clusters(recipes_df, hier_labels)
# Out:
# Cluster 1
# ----------
# chewy ginger cookies
# jude s banana muffins
# grandma clay spice cookies
# tri chocolate mousse with raspberry sauce and chocolate filigree
# mint julep cupcakes
# comforting cold and flu tea
# beer marinade for steak
# fruit and nut cookies
# yummy yogurt smoothie
# layered irish cream cake
#
#
#
# Cluster 2
# ----------
# farmhouse triple layer pumpkin cheesecake pie
# blue cheese dressing  the best
# chicken in red curry and coconut
# alex guarnaschelli s mother chicken with bbq
# meatball taco soup   crockpot
# creamy fresh herb dressing
# red wine herb marinated beef steak
# ww loaded baked potatoes
# the roosters call
# grandma s enchiladas

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 3.4 Manual interpretation of clusters
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Label the topics/themes you see in the clusters created by different clustering methods.
# 2. Do you see a common theme across clusters created by different clustering methods? Do you see any differences between the clusters created by different clustering methods?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.4
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [raw]
# common labels I saw
# cakes, cookies, drinks alcohols, breads, sweets, and not-descriptive(pink russian, el ritual, e.t.c)

# %% [raw]
# Is is quite interesting that we don't see those "cakes" and "cookies" in hierarchical clustering which appeared frequently in kmean clustering
# hierarchical clustering tends to group cakes, cookies and other sweets together rather than having a specific groups for each sweets.
# All clustering methods are prone to separate drinks and foods or especially alcohols.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# **Before submitting your assignment, please make sure you have followed all the instructions in the Submission instructions section at the top.**

# %% [markdown]
# ![](img/eva-well-done.png)
